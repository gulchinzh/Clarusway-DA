# %% [markdown]
# # Capstone Project

# %% [markdown]
# ## EDA for Car Price Prediction Model

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_json('scout_car.json', lines=True)

# %%
df.sample(20).T
# Out:
#                                                                            6376   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description              Sports Tourer Astra ST Edition 1.6 CDTI ecoFLE...
# body_type                                                          Station wagon
# price                                                                       7990
# vat                                                               VAT deductible
# km                                                                    117,583 km
# registration                                                             01/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         81 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                 [\nYes\n, \n97 g CO2/km (comb)\n]
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                     [\n100069511\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                                   NaN
# Body Color Original                                       [\nPlatin anthrazit\n]
# Upholstery                                                    [\nOther, Other\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0035/BBU\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,571 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.5 l/100 km (comb)], [4 l/100 km (city)], [...
# CO2 Emission                                            [\n97 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Cruise control, El...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, O...
# \nExtras\n                                                           [Roof rack]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nKlimaanlage, Business-Paket IntelliLink Tra...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            8401   \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                        1,4 -AUTOMATIK- 6-Stufen, 5-türig, Navi
# body_type                                                                Compact
# price                                                                      12750
# vat                                                               VAT deductible
# km                                                                     19,500 km
# registration                                                             04/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n04/2021\n, \n139 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                      [\n, \n, \n4 (Green)\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                          [\n2301\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                  [\nOnyx-Schwarz-Metallic\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,398 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[6 l/100 km (comb)], [8 l/100 km (city)], [4....
# CO2 Emission                                           [\n139 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Electrical side mirrors, Hi...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                                          [Alloy wheels, Touch screen]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Onyx Schwarz Metallic, Stoff Schwarz, 8 x...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            13535  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                         1.5 dCi 8V 75CV Start&Stop 5 porte Van
# body_type                                                                 Sedans
# price                                                                       8100
# vat                                                               VAT deductible
# km                                                                     50,052 km
# registration                                                             06/2017
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         55 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n12 months\n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                       [\n2663958\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                       [\nUni/basic\n]
# Body Color Original                                                 [\nBianco\n]
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n2\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,461 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[3.3 l/100 km (comb)], [3.5 l/100 km (city)],...
# CO2 Emission                                                                 NaN
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Alarm system, Central door lock, Driver-...
# description                    [\n, Consegna Gratuita in tutta Italia. , Ulte...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            1698   \
# url                            https://www.autoscout24.com//offers/audi-a1-1-...
# make_model                                                               Audi A1
# short_description                                   1.0 30 TFSI Sportback S-Line
# body_type                                                                Compact
# price                                                                      22490
# vat                                                               VAT deductible
# km                                                                          - km
# registration                                                                 -/-
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                                         [, New, , Super 95]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                       [\n, \n, \n110 g CO2/km (comb)\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                   [\n, \n, \nEuro 6d-TEMP\n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                                 NaN
# First Registration                                                           NaN
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                            [\nCortinaweiß\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n4\n]
# Model Code                                                        [\n0588/BHM\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[4.8 l/100 km (comb)], [5.9 l/100 km (city)],...
# CO2 Emission                                           [\n110 g CO2/km (comb)\n]
# Emission Class                                                [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n      [Air conditioning, Electrical side mirrors, Li...
# \nEntertainment & Media\n          [Bluetooth, Hands-free equipment, Radio, USB]
# \nExtras\n                       [Alloy wheels, Sport package, Sport suspension]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n- über 50 Jahren Opel - Partner, - Vertrag ...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                        NaN
# Country version                                                    [\nDenmark\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                       \nin 180 days from ordering\n
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            6077   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description               1.6 CDTi 110CV Start&Stop Sports Tourer Business
# body_type                                                          Station wagon
# price                                                                       9900
# vat                                                                         None
# km                                                                    110,005 km
# registration                                                             01/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         81 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                             [\n12 months\n, \nEuro 6\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                       [\n2640199\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                                   NaN
# Body Color Original                                           [\nGrigio scuro\n]
# Upholstery                                             [\nPart leather, Other\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,328 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.6 l/100 km (comb)], [4 l/100 km (city)], [...
# CO2 Emission                                            [\n95 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n                                                [Radio]
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nDEK:[2640199], IMM 01/2016, 110.005 KM , Op...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                          [\n01/2018\n, \n95 g CO2/km (comb)\n]
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            13016  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                        2.0 Sports Tour. Ultimate -EURO 6D-Temp
# body_type                                                          Station wagon
# price                                                                      40990
# vat                                                               VAT deductible
# km                                                                      1,000 km
# registration                                                             05/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        125 kW
# Type                            [, Demonstration, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n05/2022\n, \n150 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                          [\n, \n, \nEuro 6d-TEMP\n]
# Non-smoking Vehicle                                      [\n, \n, \n4 (Green)\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                       [\n2008514\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                           [\nOnyx Schwarz\n]
# Upholstery                                             [\nFull leather, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,956 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[5.7 l/100 km (comb)], [7.2 l/100 km (city)],...
# CO2 Emission                                           [\n150 g CO2/km (comb)\n]
# Emission Class                                                [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Digital radio, Hands-fr...
# \nExtras\n                     [Alloy wheels, Roof rack, Sport package, Sport...
# \nSafety & Security\n          [ABS, Adaptive Cruise Control, Adaptive headli...
# description                    [\n, Ausstattung:, Leichtmetallräder 20" Bicol...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            2368   \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                     Sportback sport 1,0 TFSI *SHZ*GRA*PDC*TEL*
# body_type                                                                Compact
# price                                                                      18480
# vat                                                               VAT deductible
# km                                                                      6,900 km
# registration                                                             01/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         70 kW
# Type                                              [, Employee's car, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                            [\n01/2022\n, \n97 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                       [\n275791M\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                         [\n, Red, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                   [\nMisanorot Perleffekt\n]
# Upholstery                                                     [\nCloth, Grey\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BDB\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[4.2 l/100 km (comb)], [5 l/100 km (city)], [...
# CO2 Emission                                            [\n97 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                                           [Alloy wheels, Sport seats]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Highlights:,  #Anschlussgarantie 3 Jahre ...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            12157  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                             1.5 Turbo Sports Tourer INNOVATION
# body_type                                                          Station wagon
# price                                                                      20990
# vat                                                               VAT deductible
# km                                                                     24,853 km
# registration                                                             04/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        121 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n133 g CO2/km (comb)\n]
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                            [\n94\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                           [\nOnyx Schwarz\n]
# Upholstery                                             [\nPart leather, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,490 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.8 l/100 km (comb)], [7.5 l/100 km (city)],...
# CO2 Emission                                           [\n133 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Digital radio, Hands-free equipmen...
# \nExtras\n                     [Alloy wheels, Roof rack, Sport seats, Sport s...
# \nSafety & Security\n          [ABS, Adaptive Cruise Control, Adaptive headli...
# description                    [\n, 1, ., Hand, , , Start, /, Stopp, -, Funkt...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            6621   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                     K 1.4 Turbo S&S AT ST Dyn./Navi/PDC/Sitzh.
# body_type                                                          Station wagon
# price                                                                      17000
# vat                                                               VAT deductible
# km                                                                     24,245 km
# registration                                                             02/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        110 kW
# Type                                              [, Employee's car, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                       [\n, \n, \n128 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                      [\n, \n, \n4 (Green)\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                     [\nJB 295 JO\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                      [\n, Silver, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                            [\nArgonsilber\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0035/BFM\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,399 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.6 l/100 km (comb)], [7.3 l/100 km (city)],...
# CO2 Emission                                           [\n128 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Cruise control, El...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                     [Alloy wheels, Roof rack, Ski bag, Sport seats...
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Fahrzeug steht in 14913 Jüterbog, Dennewi...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            10469  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                               1.6 CDTI 136ch Elite Auto 8cv 5p
# body_type                                                                 Sedans
# price                                                                      14999
# vat                                                               VAT deductible
# km                                                                     81,167 km
# registration                                                             04/2017
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        101 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n12 months\n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                        [\nHAE420\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                                   NaN
# Body Color Original                                           [\nGris Minéral\n]
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                                 NaN
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                            [\n, Diesel, \n]
# Consumption                                                                  NaN
# CO2 Emission                                                        [[], [], []]
# Emission Class                                                               NaN
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Daytime running lights, Driver-side airb...
# description                    [\nGris Minéral 7 Haut parleurs ABS Accoudoir ...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            1507   \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description              Sportback 1.4 TDI design Xenon Navi MediaPaket...
# body_type                                                                Compact
# price                                                                      16445
# vat                                                               VAT deductible
# km                                                                     23,934 km
# registration                                                             01/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n102 g CO2/km (comb)\n]
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# ...
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/AWJ\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,968 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,320 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.4 l/100 km (comb)], [5.2 l/100 km (city)],...
# CO2 Emission                                           [\n119 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n               [CD player, MP3, On-board computer, USB]
# \nExtras\n                                       [Sport seats, Sport suspension]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, E...
# description                    [\n,  , Garantie mit Dekra-Siegel,  gegen Zuza...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            1454   \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                Sportback 1.4 TDI design Euro 6, MMI Navi plus,
# body_type                                                                Compact
# price                                                                      15970
# vat                                                               VAT deductible
# km                                                                     25,416 km
# registration                                                             08/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                                [, Employee's car, , Diesel]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                       [\n, \n, \n109 g CO2/km (comb)\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                         [\n, \n, \nEuro 6\n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                       [\nB094087\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Blue, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                              [\nScubablau\n]
# Upholstery                                                    [\nOther, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n4\n]
# Model Code                                                        [\n0588/BDF\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,422 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# CO2 Emission                                           [\n109 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, O...
# \nExtras\n                                           [Alloy wheels, Sport seats]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Ausstattungspakete:,  Nichtraucherpaket, ...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            2848   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                   SPB Admired S-line s-tronic 1.6 Diesel 110CV
# body_type                                                                 Sedans
# price                                                                      16500
# vat                                                               VAT deductible
# km                                                                    122,584 km
# registration                                                             06/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         81 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                 [\n36 months\n, \n99 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                      [\nBA863083\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                   [\ngrey\n]
# Upholstery                                                            [\nGrey\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,355 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[], [3.5 l/100 km (city)], [3.8 l/100 km (cou...
# CO2 Emission                                            [\n99 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n      [Bluetooth, On-board computer, Radio, Sound sy...
# \nExtras\n                                         [Alloy wheels, Sport package]
# \nSafety & Security\n          [ABS, Central door lock, Fog lights, Head airb...
# description                    [\n, NESSUN VINCOLO SU FINANZIAMENTO né di alt...
# Emission Label                                                               NaN
# Gears                                                                    [\n7\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            1493
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                  Sportback 1.4TDI DESIGN 5J.GAR+XENON+NAVI+SHZ
# body_type                                                                Compact
# price                                                                      16430
# vat                                                               VAT deductible
# km                                                                     20,413 km
# registration                                                             08/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n08/2019\n, \n107 g CO2/km (comb)\n]
# Inspection new                                             [\nYes\n, \nEuro 6\n]
# Warranty                                                 [\n, \n, \n4 (Green)\n]
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                    [\nG071029328\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                 [\nMythosschwarz Metallic\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BDF\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,422 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                            [\n1,195 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# CO2 Emission                                           [\n107 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                     [Alloy wheels, Cab or rented Car, Sport seats,...
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Technik & Sicherheit:, Airbag Fahrer-/Bei...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %% [markdown]
# ### Things Needs to Be Done
#
# 1. Think about removing url column.
# 2. **Get rid of the column "make_model"**
# 3. **short description
# 4. Body_type : There are 60 nulls values that we have to deal with.
# 5. Be aware of outliers such as min. in price column.
# 6. Vat column : Change it to deductible or not deductible
# 7. For the km column remove the "km" from the rows and change the data type to int or float.
# 8. **Drop the registration column because there is another registratio colum which only contains years.**
# 9. **From prev_owner column remove the part of "previous owner" and change data type to integer. There are 6828 null values.Remove the "Previous owners" column.**
# 10. **Drop the column "kW"**
# 11. Change the "hp" column name to kW.Change the data type.
# 12. Clean the "Type" column.
# 13. **Drop the columns about inspectation.**
# 14. Come back to the Warranty column
# 15. **Drop the Full service column.**
# 16. **Drop the Non_smoking column.**
# 17. **Drop the null column.**
# 18. Clean both make and model columns.
# 19. Come back to the offer number column again.
# 20. Change the First registration column name as Registration year
# 21. **Drop the Body color original**
# 22. Organize Upholstery column
# 23. **Drop the Body column.**
# 24. Check the number of doors
# 25. For the number od seats, clean '\n'
# 26. **Drop the model code number  column**
# 27. Clean the outliers for gearing type column
# 28. For the Cyclinder column clean the outliers.
# 29. **You might drop Weight column(!)**
# 30. Make the small groups for Fuel column.
# 31. We might need the 'Consumption' to be in 3 different column.
# 32. For the CO2 Emission, get rid of the unnecessary string parts and change the column name.
# 33. For the Emission Class column be aware of empty brackets which are null valus and get rid of unnecessary inf.
# 34. Come back to the \nComfort & Convenience\n column.
# 35. Come back to '\nEntertainment & Media\n' column.
# 36. Extras column*
# 37. Safety & Security column*
# 38. **Drop the description column.**
# 39. **Drop the emission column.**
# 40. Gears column*
# 41. **Drop rest of the columns.**

# %%
df.sample(3).T
# Out:
#                                                                            11067  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                                1.4 T Selective 103 kW (140 CV)
# body_type                                                                 Sedans
# price                                                                      12450
# vat                                                               VAT deductible
# km                                                                     50,000 km
# registration                                                             09/2016
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        103 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n12 months\n
# Full Service                                                                 NaN
# Non-smoking Vehicle                            [\n, \n, \n124 g CO2/km (comb)\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                       [\n5052457\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                      [\n, Silver, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                                           [\nBlack\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,364 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,503 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.3 l/100 km (comb)], [7 l/100 km (city)], [...
# CO2 Emission                                           [\n124 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Cruise control, El...
# \nEntertainment & Media\n                                    [On-board computer]
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nPrecio financiado: 12. 450€, 199 Euros al m...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            12808  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                           Grand Sport 1.6 Innovation+OPC-Line+
# body_type                                                                 Sedans
# price                                                                      33250
# vat                                                               VAT deductible
# km                                                                         10 km
# registration                                                                 -/-
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        147 kW
# Type                                                         [, New, , Super 95]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                       [\n, \n, \n138 g CO2/km (comb)\n]
# Full Service                                          [\n, \n, \nEuro 6d-TEMP\n]
# Non-smoking Vehicle                                      [\n, \n, \n4 (Green)\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                         [\nIN054\n]
# First Registration                                                           NaN
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                           [\nOnyx Schwarz\n]
# Upholstery                                             [\nFull leather, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,600 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[6 l/100 km (comb)], [7.7 l/100 km (city)], [...
# CO2 Emission                                           [\n138 g CO2/km (comb)\n]
# Emission Class                                                [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Digital radio, Hands-free equipmen...
# \nExtras\n                     [Alloy wheels, Sport package, Sport seats, Spo...
# \nSafety & Security\n          [ABS, Adaptive headlights, Central door lock, ...
# description                    [\n, Vorbesitz: Neuwagen , Modell: Opel Insign...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                [\nNetherlands\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                      \n31/08/19\n
#
#                                                                            6337
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                        K 1.4 SIDI Turbo Innovation Aut. *NAVI*
# body_type                                                                 Sedans
# price                                                                      15990
# vat                                                                         None
# km                                                                     21,379 km
# registration                                                             06/2017
# prev_owner                                                     2 previous owners
# kW                                                                           NaN
# hp                                                                        110 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                            \n2\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                   [\n, \n, \n124 g CO2/km (comb)\n]
# Non-smoking Vehicle                                         [\n, \n, \nEuro 6\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                       [\nXT61649\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                             [\nPart leather, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,399 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5.4 l/100 km (comb)], [7.1 l/100 km (city)],...
# CO2 Emission                                           [\n124 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                           [Alloy wheels, Touch screen, Voice Control]
# \nSafety & Security\n          [ABS, Adaptive Cruise Control, Adaptive headli...
# description                    [\nSichern Sie sich diesen Opel Astra K 1.4 SI...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %%
df1 = df.copy()

# %%
#df1.drop('url', axis = 1, inplace = True)
df1.drop('make_model', axis = 1, inplace = True)
df1.drop('short_description', axis = 1, inplace = True)
df1.drop('kW', axis = 1, inplace = True)
df1.drop('registration', axis = 1, inplace = True)
df1.drop('Previous Owners', axis = 1, inplace = True)
df1.drop('Next Inspection', axis = 1, inplace = True)
df1.drop('Inspection new', axis = 1, inplace = True)
df1.drop('Full Service', axis = 1, inplace = True)
df1.drop('null', axis = 1, inplace = True)
df1.drop('Body Color Original', axis = 1, inplace = True)
df1.drop('Body', axis = 1, inplace = True)
df1.drop('Model Code', axis = 1, inplace = True)
df1.drop('Weight', axis = 1, inplace = True)
df1.drop('description', axis = 1, inplace = True)
df1.drop('Emission Label', axis = 1, inplace = True)
df1.drop('Country version', axis = 1, inplace = True)
df1.drop('Electricity consumption', axis = 1, inplace = True)
df1.drop('Last Service Date', axis = 1, inplace = True)
df1.drop('Other Fuel Types', axis = 1, inplace = True)
df1.drop('Availability', axis = 1, inplace = True)
df1.drop('Last Timing Belt Service Date', axis = 1, inplace = True)
df1.drop('Available from', axis = 1, inplace = True)
df1.drop('Non-smoking Vehicle', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-f0022fd1f4b6> in <module>
# ----> 1 df1.drop('url', axis = 1, inplace = True)
#       2 df1.drop('make_model', axis = 1, inplace = True)
#       3 df1.drop('short_description', axis = 1, inplace = True)
#       4 df1.drop('kW', axis = 1, inplace = True)
#       5 df1.drop('registration', axis = 1, inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['url'] not found in axis"

# %%
df1.drop('Offer Number', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-18bb2c2bd424> in <module>
# ----> 1 df1.drop('Offer Number', axis = 1, inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['Offer Number'] not found in axis"

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   body_type                15859 non-null  object
#  1   price                    15919 non-null  int64
#  2   vat                      11406 non-null  object
#  3   km                       14895 non-null  object
#  4   prev_owner               9091 non-null   object
#  5   kw                       15919 non-null  object
#  6   Type                     15917 non-null  object
#  7   Warranty                 10499 non-null  object
#  8   Make                     15919 non-null  object
#  9   Model                    15919 non-null  object
#  10  First Registration       14322 non-null  object
#  11  Body Color               15322 non-null  object
#  12  Paint Type               10147 non-null  object
#  13  Upholstery               12199 non-null  object
#  14  Nr. of Doors             15707 non-null  object
#  15  Nr. of Seats             14942 non-null  object
#  16  Gearing Type             15919 non-null  object
#  17  Displacement             15423 non-null  object
#  18  Cylinders                10239 non-null  object
#  19  Drive chain              9061 non-null   object
#  20  Fuel                     15919 non-null  object
#  21  Consumption              14013 non-null  object
#  22  CO2 Emission             14111 non-null  object
#  23  Emission Class           12898 non-null  object
#  24
# Comfort & Convenience
#   14999 non-null  object
#  25
# Entertainment & Media
#   14545 non-null  object
#  26
# Extras
#                  12957 non-null  object
#  27
# Safety & Security
#       14937 non-null  object
#  28  Gears                    11207 non-null  object
# dtypes: int64(1), object(28)
# memory usage: 3.5+ MB

# %%
df3 = df.copy()

# %%
df3.km = df3.km.astype('str').replace('- km', np.nan)

# %%
df3.km
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914          NaN
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918          NaN
# Name: km, Length: 15919, dtype: object

# %%
df3.km  = df3.km.str.strip(" km")

# %%
df3.km = df3.km.str.replace(",", "")

# %%
df3.km
# Out:
# 0        56013
# 1        80000
# 2        83450
# 3        73000
# 4        16200
#          ...
# 15914      NaN
# 15915     9900
# 15916       15
# 15917       10
# 15918      NaN
# Name: km, Length: 15919, dtype: object

# %%
df1.km = df3.km

# %%
df1.rename(columns={'hp':'kw'}, inplace = True )

# %%
df1.kw = df3.kw
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-16cda9bb1e5e> in <module>
# ----> 1 df1.kw = df3.kw
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'kw'

# %%
df1.kw = df3.kW

# %%
df1.kw = df1.kw.str.strip(' kW')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-0a398b711b8b> in <module>
# ----> 1 df1.kw = df1.kw.str.strip(' kW')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
#     182         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     152         from pandas.core.arrays.string_ import StringDtype
#     153
# --> 154         self._inferred_dtype = self._validate(data)
#     155         self._is_categorical = is_categorical_dtype(data.dtype)
#     156         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in _validate(data)
#     215
#     216         if inferred_dtype not in allowed_types:
# --> 217             raise AttributeError("Can only use .str accessor with string values!")
#     218         return inferred_dtype
#     219
#
# AttributeError: Can only use .str accessor with string values!

# %%
df1.sample(3).T

# %%
df1.kw = df1.kw.replace(0,np.nan)

# %%
df1.kw = df1.kw.replace('-', np.nan)

# %%
df1.kw = df1.kw.astype(float)

# %%
df1.kW

# %%
df1.prev_owner = df1.prev_owner.str.strip(' previous owner')

# %%
df1.prev_owner.value_counts()
# Out:
# 1    8294
# 2     778
# 3      17
# 4       2
# Name: prev_owner, dtype: int64

# %%
df1.prev_owner = df1.prev_owner.astype(float)

# %%
df1.prev_owner
# Out:
# 0        2.0
# 1        NaN
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 15914    NaN
# 15915    1.0
# 15916    1.0
# 15917    NaN
# 15918    1.0
# Name: prev_owner, Length: 15919, dtype: float64

# %% [markdown]
# ### Things Needs to Be Done
#
# 1. Think about removing url column.
# 2. **Get rid of the column "make_model"**
# 3. **short description
# 4. Body_type : There are 60 nulls values that we have to deal with.
# 5. Be aware of outliers such as min. in price column.
# 6. Vat column : Change it to deductible or not deductible
# 7. For the km column remove the "km" from the rows and change the data type to int or float.
# 8. **Drop the registration column because there is another registratio colum which only contains years.**
# 9. **From prev_owner column remove the part of "previous owner" and change data type to integer. There are 6828 null values.Remove the "Previous owners" column.**
# 10. **Drop the column "kW"**
# 11. Change the "hp" column name to kW.Change the data type.
# 12. Clean the "Type" column.
# 13. **Drop the columns about inspectation.**
# 14. Come back to the Warranty column
# 15. **Drop the Full service column.**
# 16. **Drop the Non_smoking column.**
# 17. **Drop the null column.**
# 18. Clean both make and model columns.
# 19. Come back to the offer number column again.
# 20. Change the First registration column name as Registration year
# 21. **Drop the Body color original**
# 22. Organize Upholstery column
# 23. **Drop the Body column.**
# 24. Check the number of doors
# 25. For the number od seats, clean '\n'
# 26. **Drop the model code number  column**
# 27. Clean the outliers for gearing type column
# 28. For the Cyclinder column clean the outliers.
# 29. **You might drop Weight column(!)**
# 30. Make the small groups for Fuel column.
# 31. We might need the 'Consumption' to be in 3 different column.
# 32. For the CO2 Emission, get rid of the unnecessary string parts and change the column name.
# 33. For the Emission Class column be aware of empty brackets which are null valus and get rid of unnecessary inf.
# 34. Come back to the \nComfort & Convenience\n column.
# 35. Come back to '\nEntertainment & Media\n' column.
# 36. Extras column*
# 37. Safety & Security column*
# 38. **Drop the description column.**
# 39. **Drop the emission column.**
# 40. Gears column*
# 41. **Drop rest of the columns.**

# %%
df2 = df1.copy()

# %%
df2.Make = df2.Make.str.strip('\n')

# %%
df1.Make = df2.Make

# %%
df1.Make
# Out:
# 0           Audi
# 1           Audi
# 2           Audi
# 3           Audi
# 4           Audi
#           ...
# 15914    Renault
# 15915    Renault
# 15916    Renault
# 15917    Renault
# 15918    Renault
# Name: Make, Length: 15919, dtype: object

# %%
df3.Model
# Out:
# 0            [\n, A1, \n]
# 1            [\n, A1, \n]
# 2            [\n, A1, \n]
# 3            [\n, A1, \n]
# 4            [\n, A1, \n]
#                ...
# 15914    [\n, Espace, \n]
# 15915    [\n, Espace, \n]
# 15916    [\n, Espace, \n]
# 15917    [\n, Espace, \n]
# 15918    [\n, Espace, \n]
# Name: Model, Length: 15919, dtype: object

# %%
df3.Model=df3.Model.str[1].str.strip('\n')

# %%
df3.Model
# Out:
# 0            A1
# 1            A1
# 2            A1
# 3            A1
# 4            A1
#           ...
# 15914    Espace
# 15915    Espace
# 15916    Espace
# 15917    Espace
# 15918    Espace
# Name: Model, Length: 15919, dtype: object

# %%
df1.Model = df3.Model

# %%
df1.sample(3).T
# Out:
#                                                                        11004  \
# body_type                                                             Sedans
# price                                                                  13500
# vat                                                           VAT deductible
# km                                                                     46897
# prev_owner                                                               1.0
# kw                                                                       NaN
# Type                                 [, Used, , Diesel (Particulate Filter)]
# Warranty                            [\n12 months\n, \n104 g CO2/km (comb)\n]
# Make                                                                    Opel
# Model                                                               Insignia
# First Registration                                            [\n, 2017, \n]
# Body Color                                                   [\n, Black, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                               [\nOther, Yellow\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,598 cc\n]
# Cylinders                                                                NaN
# Drive chain                                                              NaN
# Fuel                                   [\n, Diesel (Particulate Filter), \n]
# Consumption                [[3 l/100 km (comb)], [4 l/100 km (city)], [3 ...
# CO2 Emission                                       [\n104 g CO2/km (comb)\n]
# Emission Class                                                           NaN
# \nComfort & Convenience\n                                                NaN
# \nEntertainment & Media\n                                                NaN
# \nExtras\n                                                               NaN
# \nSafety & Security\n                                                    NaN
# Gears                                                                    NaN
#
#                                                                        4156   \
# body_type                                                             Sedans
# price                                                                  18900
# vat                                                           VAT deductible
# km                                                                     35500
# prev_owner                                                               1.0
# kw                                                                       NaN
# Type                                 [, Used, , Diesel (Particulate Filter)]
# Warranty                                                                 NaN
# Make                                                                    Audi
# Model                                                                     A3
# First Registration                                            [\n, 2017, \n]
# Body Color                                                   [\n, White, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Black\n]
# Nr. of Doors                                                         [\n4\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,598 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                   [\n, Diesel (Particulate Filter), \n]
# Consumption                [[4.2 l/100 km (comb)], [4.7 l/100 km (city)],...
# CO2 Emission                                       [\n109 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Bluetooth, CD player, Hands-free equipment, O...
# \nExtras\n                 [Alloy wheels, Sport package, Sport seats, Spo...
# \nSafety & Security\n      [ABS, Central door lock, Daytime running light...
# Gears                                                                [\n6\n]
#
#                                                                        10697
# body_type                                                      Station wagon
# price                                                                  14950
# vat                                                           VAT deductible
# km                                                                    117500
# prev_owner                                                               1.0
# kw                                                                       NaN
# Type                                 [, Used, , Diesel (Particulate Filter)]
# Warranty                                                                 NaN
# Make                                                                    Opel
# Model                                                               Insignia
# First Registration                                            [\n, 2016, \n]
# Body Color                                                   [\n, Black, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Black\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                             [\n, Automatic, \n]
# Displacement                                                  [\n1,956 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                   [\n, Diesel (Particulate Filter), \n]
# Consumption                                                              NaN
# CO2 Emission                                                             NaN
# Emission Class                                                  [[], [], []]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Bluetooth, Hands-free equipment, MP3, On-boar...
# \nExtras\n                 [Alloy wheels, Roof rack, Touch screen, Voice ...
# \nSafety & Security\n      [ABS, Adaptive headlights, Central door lock w...
# Gears                                                                [\n6\n]

# %%
df4 = df.copy()

# %%
df3.Type = df1.Type.str[1]

# %%
df1.Type = df3.Type

# %%
df3.Type.value_counts()
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# Name: Type, dtype: int64

# %%
df1.drop('Warranty', axis = 1, inplace = True)

# %%
df1.rename(columns={'Type':'Condition'}, inplace = True)

# %%
df1.rename(columns={'body_type':'Body_Type'}, inplace = True)
df1.rename(columns={'price':'Price'}, inplace = True)
df1.rename(columns={'vat':'Vat'}, inplace = True)
df1.rename(columns={'prev_owner':'Previous_Owner'}, inplace = True)
df1.rename(columns={'First Registration':'Registration_Year'}, inplace = True)
df1.rename(columns={'Body Color':'Body_Color'}, inplace = True)
df1.rename(columns={'Paint Type':'Paint_Type'}, inplace = True)
df1.rename(columns={'Nr. of Doors':'Nr_of_Doors'}, inplace = True)
df1.rename(columns={'Nr. of Seats':'Nr_of_Seats'}, inplace = True)
df1.rename(columns={'Gearing Type':'Gearing_Type'}, inplace = True)
df1.rename(columns={'CO2 Emission':'CO2_Emission'}, inplace = True)
df1.rename(columns={'Emission Class':'Emission_Class'}, inplace = True)
df1.rename(columns={'\nComfort & Convenience\n':'Comfort_Convenience'}, inplace = True)
df1.rename(columns={'\nEntertainment & Media\n':'Entertainment_Media'}, inplace = True)
df1.rename(columns={'\nExtras\n':'Extras'}, inplace = True)
df1.rename(columns={'\nSafety & Security\n':'Safety & Security'}, inplace = True)
df1.rename(columns={'kw':'kW'}, inplace = True)

# %%
df1.rename(columns={'Safety & Security':'Safety_Security'}, inplace = True)

# %%
df1.rename(columns={'Drive chain':'Drive_Chain'}, inplace = True)

# %%
df1.rename(columns={'km':'Km'}, inplace = True)

# %%
df1.sample(3).T
# Out:
#                                                                   6010  \
# Body_Type                                                Station wagon
# Price                                                            11600
# Vat                                                               None
# Km                                                               69459
# Previous_Owner                                                     1.0
# kW                                                                 NaN
# Condition                                                         Used
# Make                                                              Opel
# Model                                                            Astra
# Registration_Year                                       [\n, 2017, \n]
# Body_Color                                             [\n, Black, \n]
# Paint_Type                                                         NaN
# Upholstery                                                         NaN
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                              [\n998 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                [\nfront\n]
# Fuel                                                [\n, Gasoline, \n]
# Consumption                                                        NaN
# CO2_Emission                                              [[], [], []]
# Emission_Class                                                     NaN
# Comfort_Convenience  [Air conditioning, Electrical side mirrors, Le...
# Entertainment_Media         [Bluetooth, On-board computer, Radio, USB]
# Extras                                                             NaN
# Safety_Security      [Alarm system, Central door lock, Driver-side ...
# Gears                                                              NaN
#
#                                                                   8617  \
# Body_Type                                                      Compact
# Price                                                             7480
# Vat                                                     VAT deductible
# Km                                                               55800
# Previous_Owner                                                     NaN
# kW                                                                 NaN
# Condition                                                         Used
# Make                                                              Opel
# Model                                                            Corsa
# Registration_Year                                       [\n, 2016, \n]
# Body_Color                                               [\n, Red, \n]
# Paint_Type                                                         NaN
# Upholstery                                                 [\nCloth\n]
# Nr_of_Doors                                                    [\n3\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,229 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                        NaN
# Fuel                           [\n, Super 95 / Regular/Benzine 91, \n]
# Consumption          [\n, 5.4 l/100 km (comb), \n, 6.7 l/100 km (ci...
# CO2_Emission                                 [\n128 g CO2/km (comb)\n]
# Emission_Class                                                     NaN
# Comfort_Convenience  [Air conditioning, Electrical side mirrors, Hi...
# Entertainment_Media                         [On-board computer, Radio]
# Extras                                                             NaN
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                          [\n5\n]
#
#                                                                   7017
# Body_Type                                                       Sedans
# Price                                                            11700
# Vat                                                               None
# Km                                                               62301
# Previous_Owner                                                     1.0
# kW                                                                 NaN
# Condition                                                         Used
# Make                                                              Opel
# Model                                                            Astra
# Registration_Year                                       [\n, 2017, \n]
# Body_Color                                            [\n, Silver, \n]
# Paint_Type                                                         NaN
# Upholstery                                                         NaN
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,364 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                [\nfront\n]
# Fuel                                                [\n, Gasoline, \n]
# Consumption                                                        NaN
# CO2_Emission                                              [[], [], []]
# Emission_Class                                                     NaN
# Comfort_Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment_Media                                 [CD player, Radio]
# Extras                                                             NaN
# Safety_Security      [Driver-side airbag, Electronic stability cont...
# Gears                                                              NaN

# %%
df1.First_Registration = df3['First Registration'].str[1]

# %%
df1.sample(3).T
# Out:
#                                                                  12721  \
# Body_Type                                                       Sedans
# Price                                                            27804
# Vat                                                               None
# Km                                                                 NaN
# Previous_Owner                                                     NaN
# kW                                                                 NaN
# Condition                                                          New
# Make                                                              Opel
# Model                                                         Insignia
# Registration_Year                                                  NaN
# Body_Color                                                         NaN
# Paint_Type                                                         NaN
# Upholstery                                                         NaN
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,956 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                [\nfront\n]
# Fuel                                                  [\n, Diesel, \n]
# Consumption          [[5 l/100 km (comb)], [6 l/100 km (city)], [4 ...
# CO2_Emission                                                       NaN
# Emission_Class                                                     NaN
# Comfort_Convenience                                                NaN
# Entertainment_Media                                                NaN
# Extras                                                             NaN
# Safety_Security                                                    NaN
# Gears                                                          [\n8\n]
#
#                                                                  1632   \
# Body_Type                                                       Sedans
# Price                                                            22000
# Vat                                                   Price negotiable
# Km                                                               27000
# Previous_Owner                                                     1.0
# kW                                                                 NaN
# Condition                                               Employee's car
# Make                                                              Audi
# Model                                                               A1
# Registration_Year                                       [\n, 2018, \n]
# Body_Color                                              [\n, Grey, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                                         NaN
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n4\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,395 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                        NaN
# Fuel                                                [\n, Gasoline, \n]
# Consumption          [[4.9 l/100 km (comb)], [6.2 l/100 km (city)],...
# CO2_Emission                                 [\n112 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, M...
# Extras               [Alloy wheels, Sport package, Sport seats, Spo...
# Safety_Security      [ABS, Central door lock, Central door lock wit...
# Gears                                                          [\n7\n]
#
#                                                                  8331
# Body_Type                                                      Compact
# Price                                                            13490
# Vat                                                     VAT deductible
# Km                                                               10000
# Previous_Owner                                                     1.0
# kW                                                                 NaN
# Condition                                                         Used
# Make                                                              Opel
# Model                                                            Corsa
# Registration_Year                                       [\n, 2018, \n]
# Body_Color                                             [\n, White, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                          [\nCloth, Black\n]
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,398 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                        NaN
# Fuel                           [\n, Super 95 / Regular/Benzine 91, \n]
# Consumption          [\n, 6.3 l/100 km (comb), \n, 7.8 l/100 km (ci...
# CO2_Emission                                 [\n143 g CO2/km (comb)\n]
# Emission_Class                                                     NaN
# Comfort_Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, M...
# Extras                   [Alloy wheels, Sport seats, Sport suspension]
# Safety_Security      [ABS, Adaptive headlights, Central door lock, ...
# Gears                                                          [\n5\n]

# %% [markdown]
# 1. Create age column.

# %% [markdown]
# ### Things Needs to Be Done
#
# 1. Think about removing url column.
# 2. **Get rid of the column "make_model"**
# 3. **short description
# 4. Body_type : There are 60 nulls values that we have to deal with.
# 5. Be aware of outliers such as min. in price column.
# 6. Vat column : Change it to deductible or not deductible
# 7. For the km column remove the "km" from the rows and change the data type to int or float.
# 8. **Drop the registration column because there is another registratio colum which only contains years.**
# 9. **From prev_owner column remove the part of "previous owner" and change data type to integer. There are 6828 null values.Remove the "Previous owners" column.**
# 10. **Drop the column "kW"**
# 11. Change the "hp" column name to kW.Change the data type.
# 12. Clean the "Type" column.
# 13. **Drop the columns about inspectation.**
# 14. Come back to the Warranty column
# 15. **Drop the Full service column.**
# 16. **Drop the Non_smoking column.**
# 17. **Drop the null column.**
# 18. Clean both make and model columns.
# 19. Come back to the offer number column again.
# 20. Change the First registration column name as Registration year
# 21. **Drop the Body color original**
# 22. Organize Upholstery column
# 23. **Drop the Body column.**
# 24. Check the number of doors
# 25. For the number od seats, clean '\n'
# 26. **Drop the model code number  column**
# 27. Clean the outliers for gearing type column
# 28. For the Cyclinder column clean the outliers.
# 29. **You might drop Weight column(!)**
# 30. Make the small groups for Fuel column.
# 31. We might need the 'Consumption' to be in 3 different column.
# 32. For the CO2 Emission, get rid of the unnecessary string parts and change the column name.
# 33. For the Emission Class column be aware of empty brackets which are null valus and get rid of unnecessary inf.
# 34. Come back to the \nComfort & Convenience\n column.
# 35. Come back to '\nEntertainment & Media\n' column.
# 36. Extras column*
# 37. Safety & Security column*
# 38. **Drop the description column.**
# 39. **Drop the emission column.**
# 40. Gears column*
# 41. **Drop rest of the columns.**

# %%
df1.Body_Color = df1.Body_Color.str[1]

# %%
df1["Upholstery"] = df1["Upholstery"].apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Upholstery
# Out:
# 0               \nCloth, Black\n
# 1                \nCloth, Grey\n
# 2               \nCloth, Black\n
# 3                            NaN
# 4               \nCloth, Black\n
#                   ...
# 15914                        NaN
# 15915                  \nCloth\n
# 15916    \nFull leather, Black\n
# 15917           \nPart leather\n
# 15918    \nFull leather, Brown\n
# Name: Upholstery, Length: 15919, dtype: object

# %%
df1.Upholstery = df1.Upholstery.str.strip("\n")

# %%
df1.Upholstery.value_counts()
# Out:
# Cloth, Black           5821
# Part leather, Black    1121
# Cloth                  1005
# Cloth, Grey             891
# Cloth, Other            639
# Full leather, Black     575
# Black                   491
# Grey                    273
# Other, Other            182
# Part leather            140
# Full leather            139
# Part leather, Grey      116
# Full leather, Brown     116
# Other, Black            110
# Full leather, Other      72
# Full leather, Grey       67
# Part leather, Other      65
# Other                    56
# Part leather, Brown      50
# alcantara, Black         47
# Velour, Black            36
# Full leather, Beige      36
# Cloth, Brown             28
# Velour                   16
# Other, Grey              15
# Cloth, Beige             13
# Brown                    12
# Cloth, Blue              12
# Cloth, White              8
# Velour, Grey              8
# alcantara, Grey           6
# Cloth, Red                5
# Other, Yellow             4
# Beige                     3
# Part leather, Red         3
# alcantara                 2
# alcantara, Other          2
# Full leather, Blue        2
# White                     2
# Part leather, White       2
# Blue                      2
# Part leather, Beige       2
# Cloth, Orange             1
# Full leather, Red         1
# Other, Brown              1
# Full leather, White       1
# Name: Upholstery, dtype: int64

# %%
df1.Paint_Type = df1["Paint_Type"].apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Paint_Type = df1.Paint_Type.str.strip('\n')

# %%
df1.Paint_Type
# Out:
# 0        Metallic
# 1             NaN
# 2        Metallic
# 3        Metallic
# 4        Metallic
#            ...
# 15914    Metallic
# 15915    Metallic
# 15916         NaN
# 15917         NaN
# 15918    Metallic
# Name: Paint_Type, Length: 15919, dtype: object

# %%
df1.Nr_of_Doors = df1.Nr_of_Doors.apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Nr_of_Doors = df1.Nr_of_Doors.str.strip('\n')

# %%
df1.Nr_of_Seats = df1.Nr_of_Seats.apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Nr_of_Seats = df1.Nr_of_Seats.str.strip('\n')

# %%
df1.sample(3).T

# %%
df1.Gearing_Type = df1.Gearing_Type.apply(lambda item: item[1] if type(item) == list else item)
df1.Gearing_Type = df1.Gearing_Type.str.strip('\n')

# %%
df1.Gearing_Type = df1.Gearing_Type.str.strip('\n')

# %%
df1.Gearing_Type

# %%
df1.Displacement = df3.Displacement

# %%
df1.Displacement = df1.Displacement.apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Displacement = df1.Displacement.str.strip('\n').str.strip(' cc\n')

# %%
df1.Displacement  = df1.Displacement.str.replace(',','')

# %%
df1.Displacement=df1.Displacement.astype(float)

# %%
df1.Cylinders = df1.Cylinders.str[0].str.strip('\n').astype(float)

# %%
df1.Drive_Chain = df1.Drive_Chain.str[0].str.strip('\n')

# %%
df1.Fuel = df1.Fuel.str[1].str.strip('\n')

# %%
df1.Fuel

# %%
def Fuel_type(x):
    if "Benzine" in x :
        return "Gasoline"
    elif "Gasoline" in x :
        return "Gasoline"
    elif "Super" in x :
        return "Gasoline"
    elif "Diesel" in x :
        return "Diesel"
    elif "LPG" in x :
        return "LPG"
    else :
        return "Others"

# %%
df1.Fuel = df1.Fuel.apply(Fuel_type)

# %%
df1.Fuel.value_counts()

# %%
df1['Combined'] = df1.Consumption.str[0].str[0]

# %%
df1.Combined = df1.Consumption.str[0].str[0].str.split().str[0]

# %%
df1.Combined_Cons = df1.Combined

# %%
df1.Combined_Cons

# %%
df1.Combined_Cons=df1.Combined.astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-dec53561c535> in <module>
# ----> 1 df1.Combined_Cons=df1.Combined.astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Combined'

# %%
df1.Combined_Cons

# %%
df1.City_Cons = df1.Consumption.str[1].str[0].str.split().str[0].astype(float)

# %%
df1.City_Cons

# %%
df1.Highway_Cons = df1.Consumption.str[2].str[0].str.split().str[0].astype(float)

# %%
df1.Highway_Cons

# %%
df1.sample(3).T
# Out:
#                                                                        13418  \
# body_type                                                             Sedans
# price                                                                  10500
# vat                                                                     None
# km                                                                     78851
# prev_owner                                                              None
# kw                                                                     66 kW
# Type                                                      [, Used, , Diesel]
# Warranty                                                       \n12 months\n
# Make                                                             \nRenault\n
# Model                                                         [\n, Clio, \n]
# First Registration                                            [\n, 2016, \n]
# Body Color                                                   [\n, White, \n]
# Paint Type                                                               NaN
# Upholstery                                                               NaN
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                             [\n, Automatic, \n]
# Displacement                                                  [\n1,461 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                              NaN
# Fuel                                                        [\n, Diesel, \n]
# Consumption                                  [[3.5 l/100 km (comb)], [], []]
# CO2 Emission                                        [\n92 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Cruise control, Hill Holder...
# \nEntertainment & Media\n               [MP3, On-board computer, Radio, USB]
# \nExtras\n                                                               NaN
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# Gears                                                                [\n6\n]
#
#                                                                        6368   \
# body_type                                                             Sedans
# price                                                                  15990
# vat                                                                     None
# km                                                                     21379
# prev_owner                                                 2 previous owners
# kw                                                                    110 kW
# Type                                                    [, Used, , Gasoline]
# Warranty                                                                 NaN
# Make                                                                \nOpel\n
# Model                                                        [\n, Astra, \n]
# First Registration                                            [\n, 2017, \n]
# Body Color                                                    [\n, Grey, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                         [\nPart leather, Black\n]
# Nr. of Doors                                                         [\n4\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                             [\n, Automatic, \n]
# Displacement                                                  [\n1,399 cc\n]
# Cylinders                                                                NaN
# Drive chain                                                              NaN
# Fuel                                                      [\n, Gasoline, \n]
# Consumption                [[5.4 l/100 km (comb)], [7.1 l/100 km (city)],...
# CO2 Emission                                       [\n124 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                       [Alloy wheels, Touch screen, Voice Control]
# \nSafety & Security\n      [ABS, Adaptive Cruise Control, Adaptive headli...
# Gears                                                                    NaN
#
#                                                                        9810
# body_type                                                            Compact
# price                                                                   9880
# vat                                                           VAT deductible
# km                                                                       NaN
# prev_owner                                                              None
# kw                                                                     51 kW
# Type                                     [, New, , Super 95 / Super Plus 98]
# Warranty                   [\n, \n, \n, 5.6 l/100 km (comb), \n, 7.3 l/10...
# Make                                                                \nOpel\n
# Model                                                        [\n, Corsa, \n]
# First Registration                                                       NaN
# Body Color                                                    [\n, Blue, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Black\n]
# Nr. of Doors                                                         [\n3\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,229 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                      [\n, Super 95 / Super Plus 98, \n]
# Consumption                [\n, 5.6 l/100 km (comb), \n, 7.3 l/100 km (ci...
# CO2 Emission                                       [\n129 g CO2/km (comb)\n]
# Emission Class                                            [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n  [Air conditioning, Electrical side mirrors, Hi...
# \nEntertainment & Media\n  [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                                                               NaN
# \nSafety & Security\n      [ABS, Central door lock, Daytime running light...
# Gears                                                                [\n5\n]

# %%
df1.CO2_Emission = df1.CO2_Emission.str[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-9afda2b31574> in <module>
# ----> 1 df1.CO2_Emission = df1.CO2_Emission.str[0]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'CO2_Emission'

# %%
df1.CO2_Emission

# %%
df1.CO2_Emission = df1.CO2_Emission.str.strip(' g CO2/km (comb)\n').str.replace(',',"")

# %%
df1.CO2_Emission
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-a68fee2f6e1c> in <module>
# ----> 1 df1.CO2_Emission
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'CO2_Emission'

# %%
df1.CO2_Emission = df1.CO2_Emission.astype(float)

# %%
df1.Emission_Class = df1.Emission_Class.str[0].str.strip('\n')

# %%
df1.Emission_Class.value_counts()

# %%
df1.Gears = df1.Gears.str[0].str.strip('\n')

# %%
df1.Gears = df1.Gears.astype(float)

# %%
df1.Gears
# Out:
# 0        NaN
# 1        7.0
# 2        NaN
# 3        6.0
# 4        NaN
#         ...
# 15914    6.0
# 15915    7.0
# 15916    6.0
# 15917    6.0
# 15918    NaN
# Name: Gears, Length: 15919, dtype: float64

# %%
df1.drop('Consumption', axis = 1, inplace = True)

# %%
df1.sample(3).T
# Out:
#                                                                         546   \
# body_type                                                            Compact
# price                                                                  13800
# vat                                                           VAT deductible
# km                                                                     94800
# prev_owner                                                              None
# kw                                                                     66 kW
# Type                                                      [, Used, , Diesel]
# Warranty                                                                  \n
# Make                                                                \nAudi\n
# Model                                                           [\n, A1, \n]
# First Registration                                            [\n, 2016, \n]
# Body Color                                                    [\n, Grey, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                       [\nOther\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,422 cc\n]
# Cylinders                                                                NaN
# Drive chain                                                              NaN
# Fuel                                                        [\n, Diesel, \n]
# CO2 Emission                                        [\n91 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Bluetooth, CD player, On-board computer, Radi...
# \nExtras\n                                                    [Alloy wheels]
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, I...
# Gears                                                                    NaN
#
#                                                                         3714  \
# body_type                                                             Sedans
# price                                                                  22222
# vat                                                                     None
# km                                                                     24000
# prev_owner                                                  1 previous owner
# kw                                                                     85 kW
# Type                                                    [, Used, , Super 95]
# Warranty                                   [\n, \n, \n107 g CO2/km (comb)\n]
# Make                                                                \nAudi\n
# Model                                                           [\n, A3, \n]
# First Registration                                            [\n, 2017, \n]
# Body Color                                                    [\n, Blue, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Black\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                             NaN
# Gearing Type                                             [\n, Automatic, \n]
# Displacement                                                    [\n999 cc\n]
# Cylinders                                                            [\n3\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                                      [\n, Super 95, \n]
# CO2 Emission                                       [\n107 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Bluetooth, CD player, Digital radio, Hands-fr...
# \nExtras\n                 [Alloy wheels, Roof rack, Shift paddles, Ski b...
# \nSafety & Security\n      [ABS, Adaptive headlights, Alarm system, Centr...
# Gears                                                                    NaN
#
#                                                                         8736
# body_type                                                             Sedans
# price                                                                   7000
# vat                                                                     None
# km                                                                     35000
# prev_owner                                                  1 previous owner
# kw                                                                     55 kW
# Type                                 [, Used, , Diesel (Particulate Filter)]
# Warranty                                                                 NaN
# Make                                                                \nOpel\n
# Model                                                        [\n, Corsa, \n]
# First Registration                                            [\n, 2017, \n]
# Body Color                                                  [\n, Silver, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Other\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,248 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                   [\n, Diesel (Particulate Filter), \n]
# CO2 Emission                                                             NaN
# Emission Class                                                  [[], [], []]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Electrical side mi...
# \nEntertainment & Media\n  [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                                                    [Alloy wheels]
# \nSafety & Security\n      [ABS, Alarm system, Central door lock with rem...
# Gears                                                                    5.0

# %%
df1.isnull().sum()
# Out:
# body_type                      60
# price                           0
# vat                          4513
# km                           1024
# prev_owner                   6828
# kw                              0
# Type                            2
# Warranty                     5420
# Make                            0
# Model                           0
# First Registration           1597
# Body Color                    597
# Paint Type                   5772
# Upholstery                   3720
# Nr. of Doors                  212
# Nr. of Seats                  977
# Gearing Type                    0
# Displacement                  496
# Cylinders                    5680
# Drive chain                  6858
# Fuel                            0
# CO2 Emission                 1808
# Emission Class               3021
# \nComfort & Convenience\n     920
# \nEntertainment & Media\n    1374
# \nExtras\n                   2962
# \nSafety & Security\n         982
# Gears                        4712
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# <br>

# %%
df1.sample(3).T
# Out:
#                                                                        14879  \
# body_type                                                      Station wagon
# price                                                                  10964
# vat                                                           VAT deductible
# km                                                                        10
# prev_owner                                                              None
# kw                                                                     66 kW
# Type                                                     [, New, , Super 95]
# Warranty                                   [\n, \n, \n113 g CO2/km (comb)\n]
# Make                                                             \nRenault\n
# Model                                                         [\n, Clio, \n]
# First Registration                                                       NaN
# Body Color                                                               NaN
# Paint Type                                                               NaN
# Upholstery                                                               NaN
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                             NaN
# Cylinders                                                                NaN
# Drive chain                                                      [\nfront\n]
# Fuel                                                      [\n, Super 95, \n]
# CO2 Emission                                       [\n113 g CO2/km (comb)\n]
# Emission Class                                                 [\nEuro 6d\n]
# \nComfort & Convenience\n  [Air conditioning, Cruise control, Leather ste...
# \nEntertainment & Media\n  [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                                                               NaN
# \nSafety & Security\n      [ABS, Central door lock, Daytime running light...
# Gears                                                                    6.0
#
#                                                                        4179   \
# body_type                                                             Sedans
# price                                                                  18995
# vat                                                           VAT deductible
# km                                                                     15200
# prev_owner                                                  1 previous owner
# kw                                                                     85 kW
# Type                                 [, Used, , Diesel (Particulate Filter)]
# Warranty                                                                 NaN
# Make                                                                \nAudi\n
# Model                                                           [\n, A3, \n]
# First Registration                                            [\n, 2018, \n]
# Body Color                                                    [\n, Blue, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Black\n]
# Nr. of Doors                                                         [\n4\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,598 cc\n]
# Cylinders                                                                NaN
# Drive chain                                                              NaN
# Fuel                                   [\n, Diesel (Particulate Filter), \n]
# CO2 Emission                                       [\n109 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Bluetooth, CD player, Digital radio, Hands-fr...
# \nExtras\n                                     [Alloy wheels, Voice Control]
# \nSafety & Security\n      [ABS, Alarm system, Central door lock, Daytime...
# Gears                                                                    NaN
#
#                                                                        6593
# body_type                                                      Station wagon
# price                                                                  17700
# vat                                                         Price negotiable
# km                                                                     56000
# prev_owner                                                  1 previous owner
# kw                                                                    100 kW
# Type                                                      [, Used, , Diesel]
# Warranty                                                                 NaN
# Make                                                                \nOpel\n
# Model                                                        [\n, Astra, \n]
# First Registration                                            [\n, 2017, \n]
# Body Color                                                    [\n, Grey, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                         [\nFull leather, Black\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                             [\n, Automatic, \n]
# Displacement                                                  [\n1,598 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                                        [\n, Diesel, \n]
# CO2 Emission                                       [\n119 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Bluetooth, Hands-free equipment, MP3, On-boar...
# \nExtras\n                       [Alloy wheels, Touch screen, Voice Control]
# \nSafety & Security\n      [ABS, Adaptive headlights, Alarm system, Blind...
# Gears                                                                    6.0

# %%
df1.Registration_Year = df1.Registration_Year.str[1].astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-5757b741bbf2> in <module>
# ----> 1 df1.Registration_Year = df1.Registration_Year.str[1].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Registration_Year'

# %%
df1.Registration_Year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-d125e9168568> in <module>
# ----> 1 df1.Registration_Year
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Registration_Year'

# %%
df1.to_csv("df1_clean.csv", index = False)
